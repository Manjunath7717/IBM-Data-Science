# %% [markdown]
# # Learning FourSquare API with Python

# %% [markdown]
# ## Introduction
#
# In this lab, you will learn in details how to make calls to the Foursquare API for different purposes. You will learn how to construct a URL to send a request to the API to search for a specific type of venues, to explore a particular venue, to explore a Foursquare user, to explore a geographical location, and to get trending venues around a location. Also, you will learn how to use the visualization library, Folium, to visualize the results.

# %% [markdown]
# ## Table of Contents
#
# 1. <a href="#item1">Foursquare API Search Function</a>
# 2. <a href="#item2">Explore a Given Venue</a>
# 3. <a href="#item3">Explore a User</a>
# 4. <a href="#item4">Foursquare API Explore Function</a>
# 5. <a href="#item5">Get Trending Venues</a>

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# Warning: 2 possible package resolutions (only showing differing packages):
#   - anaconda/osx-64::openssl-1.1.1d-h1de35cc_2
#   - defaults/osx-64::openssl-1.1.1d-h1de35ccdone
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %% [markdown]
# ##### Make sure that you have created a Foursquare developer account and have your credentials handy

# %%
CLIENT_ID = 'IBFYFDBJUDEPCXTT1LLG3PXQBJNW5HOSGWS1GB0I2MM5COMC' # your Foursquare ID
CLIENT_SECRET = 'PT3YWES5EZX30CBHCEBXUSKCNDC0MBQXCSP4PPMY04BPIFJX' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IBFYFDBJUDEPCXTT1LLG3PXQBJNW5HOSGWS1GB0I2MM5COMC
# CLIENT_SECRET:PT3YWES5EZX30CBHCEBXUSKCNDC0MBQXCSP4PPMY04BPIFJX

# %% [markdown]
# #### Let's again assume that you are staying at the Conrad hotel. So let's start by converting the Contrad Hotel's address to its latitude and longitude coordinates.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = '102 North End Ave, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7151482 -74.0156573

# %% [markdown]
# ## 1. Search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Now, let's assume that it is lunch time, and you are craving Italian food. So, let's define a query to search for Italian food that is within 500 metres from the Conrad Hotel.

# %%
search_query = 'Coffee'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Coffee .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IBFYFDBJUDEPCXTT1LLG3PXQBJNW5HOSGWS1GB0I2MM5COMC&client_secret=PT3YWES5EZX30CBHCEBXUSKCNDC0MBQXCSP4PPMY04BPIFJX&ll=40.7151482,-74.0156573&v=20180604&query=Coffee&radius=500&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ee1ca6cede9ed0aedbf0b8a'},
#  'response': {'venues': [{'id': '5dba113267232c000803cb37',
#     'name': 'For Five Coffee Roasters',
#     'location': {'lat': 40.71224,
#      'lng': -74.014915,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71224,
#        'lng': -74.014915}],
#      'distance': 329,
#      'postalCode': '10280',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10280', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '4f241551e4b01b0c5f0f1361',
#     'name': 'WFM Coffee Bar',
#     'location': {'address': '270 Greenwich St',
#      'crossStreet': 'Warren St',
#      'lat': 40.71554183959961,
#      'lng': -74.01143646240234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71554183959961,
#        'lng': -74.01143646240234}],
#      'distance': 358,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['270 Greenwich St (Warren St)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '50a38463e4b0d1371722335f',
#     'name': 'Hudson/Chambers Coffee Cart',
#     'location': {'address': 'Chambers St',
#      'crossStreet': 'at Hudson St',
#      'lat': 40.71563827489798,
#      'lng': -74.00961280945921,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71563827489798,
#        'lng': -74.00961280945921}],
#      'distance': 512,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Chambers St (at Hudson St)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '4e4dd91ebd41b76bef941ef0',
#     'name': 'The Coffee Beanery',
#     'location': {'address': '30 Mall Dr W',
#      'lat': 40.714628867075795,
#      'lng': -74.01581943213544,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.714628867075795,
#        'lng': -74.01581943213544}],
#      'distance': 59,
#      'postalCode': '07310',
#      'cc': 'US',
#      'city': 'Jersey City',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['30 Mall Dr W',
#       'Jersey City, NY 07310',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '5bbb56cba306190039f416a4',
#     'name': 'Coffee by La Colombe Coffee Roasters',
#     'location': {'lat': 40.713416,
#      'lng': -74.015191,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713416,
#        'lng': -74.015191}],
#      'distance': 196,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10007', 'United States']},
#     'categories': [{'id': '5665c7b9498e7d8a4f2c0f06',
#       'name': 'Corporate Coffee Shop',
#       'pluralName': 'Corporate Coffee Shops',
#       'shortName': 'Corporate Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '58ece658424f93769dfd45d5',
#     'name': '3rd Floor Coffee Bar',
#     'location': {'address': '200 West St',
#      'crossStreet': 'Murray St',
#      'lat': 40.714756887763514,
#      'lng': -74.01432935786255,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.714756887763514,
#        'lng': -74.01432935786255}],
#      'distance': 120,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 West St (Murray St)',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '5665c7b9498e7d8a4f2c0f06',
#       'name': 'Corporate Coffee Shop',
#       'pluralName': 'Corporate Coffee Shops',
#       'shortName': 'Corporate Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '50202b0ee4b0cabb110c01a2',
#     'name': 'Laughing Man Coffee & Tea',
#     'location': {'address': '1 N End Ave',
#      'lat': 40.71475351814522,
#      'lng': -74.01736807400145,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71475351814522,
#        'lng': -74.01736807400145}],
#      'distance': 150,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 N End Ave',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '73541538'},
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '4e6ded5e45dd293273a36c79',
#     'name': 'Coffee Cart',
#     'location': {'crossStreet': 'Greenwich St & Murray St',
#      'lat': 40.715330652026495,
#      'lng': -74.0115616679081,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.715330652026495,
#        'lng': -74.0115616679081}],
#      'distance': 346,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Greenwich St & Murray St',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '502a4fe7e4b0930e7b11b3c0',
#     'name': 'Coffee Cart (South End & Albany)',
#     'location': {'lat': 40.711431094887175,
#      'lng': -74.01584238478515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.711431094887175,
#        'lng': -74.01584238478515}],
#      'distance': 414,
#      'postalCode': '10280',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10280', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '5214cdc411d2f67e0de859f4',
#     'name': '38th floor coffee cart',
#     'location': {'address': '200 Vesey St',
#      'lat': 40.714010586387985,
#      'lng': -74.01364465606443,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.714010586387985,
#        'lng': -74.01364465606443}],
#      'distance': 211,
#      'postalCode': '10281',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 Vesey St',
#       'New York, NY 10281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '4fc3bca5e4b0557039dd4ccd',
#     'name': 'Coffee & Lunch',
#     'location': {'address': '185 Greenwich St',
#      'lat': 40.711541975062225,
#      'lng': -74.01284130244078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.711541975062225,
#        'lng': -74.01284130244078}],
#      'distance': 466,
#      'postalCode': '10007',
#      'cc': 'US',
#      'neighborhood': 'Financial District',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['185 Greenwich St',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d17a941735',
#       'name': 'Cajun / Creole Restaurant',
#       'pluralName': 'Cajun / Creole Restaurants',
#       'shortName': 'Cajun / Creole',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '597a11ccb2958f056b27c60d',
#     'name': 'Jack’s Stir Brew Coffee',
#     'location': {'address': '139 Reade St',
#      'crossStreet': 'Hudson/Greenwich',
#      'lat': 40.71645048567266,
#      'lng': -74.0097547321717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71645048567266,
#        'lng': -74.0097547321717},
#       {'label': 'entrance', 'lat': 40.716363, 'lng': -74.009808}],
#      'distance': 518,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['139 Reade St (Hudson/Greenwich)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '4f3215d419836c91c7b4493b',
#     'name': 'Coffee Cuisine of Church St',
#     'location': {'address': '100 Church St',
#      'lat': 40.712952,
#      'lng': -74.009491,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.712952,
#        'lng': -74.009491}],
#      'distance': 574,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['100 Church St',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '4d89044e6daeb60c33a846e0',
#     'name': 'Sky Lobby Coffee Bar',
#     'location': {'address': '200 West St',
#      'crossStreet': 'at Murray St.',
#      'lat': 40.71470811444494,
#      'lng': -74.01440442999716,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71470811444494,
#        'lng': -74.01440442999716}],
#      'distance': 116,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 West St (at Murray St.)',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '54f4ba06498e2cf5561da814',
#       'name': 'Corporate Cafeteria',
#       'pluralName': 'Corporate Cafeterias',
#       'shortName': 'Corporate Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '57210afa498ecfbb8c1be6cc',
#     'name': 'Le District Coffee',
#     'location': {'address': '225 Liberty St',
#      'crossStreet': 'at West St',
#      'lat': 40.71328360114957,
#      'lng': -74.01585448223682,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71328360114957,
#        'lng': -74.01585448223682}],
#      'distance': 208,
#      'postalCode': '10281',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['225 Liberty St (at West St)',
#       'New York, NY 10281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '4ea0afbf9adf1e334e4cc0e6',
#     'name': 'Laughing Man Coffee & Tea',
#     'location': {'address': '184 Duane St',
#      'crossStreet': 'btwn Greenwich & Hudson St.',
#      'lat': 40.7173944529165,
#      'lng': -74.01010324607125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7173944529165,
#        'lng': -74.01010324607125}],
#      'distance': 531,
#      'postalCode': '10013',
#      'cc': 'US',
#      'neighborhood': 'Tribeca',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['184 Duane St (btwn Greenwich & Hudson St.)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '73541580'},
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '4e7e41b87beb96a21aba4704',
#     'name': 'Coffee &  Donut Cart',
#     'location': {'address': 'Barclay st',
#      'crossStreet': 'Church st',
#      'lat': 40.71268922492194,
#      'lng': -74.00998547673225,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71268922492194,
#        'lng': -74.00998547673225}],
#      'distance': 551,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Barclay st (Church st)',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '4f7c472de4b09b8aeaed0826',
#     'name': 'MBJ Coffee Kiosk @ BMCC',
#     'location': {'address': '199 Chambers St, New York, NY 10013',
#      'lat': 40.7169900862958,
#      'lng': -74.0120207306095,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7169900862958,
#        'lng': -74.0120207306095}],
#      'distance': 369,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['199 Chambers St, New York, NY 10013',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '52a3a47e11d2b5d5943d33dc',
#     'name': 'I m a coffee',
#     'location': {'address': '9 Saint Marks Pl',
#      'lat': 40.72948455810547,
#      'lng': -73.98905944824219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72948455810547,
#        'lng': -73.98905944824219}],
#      'distance': 2753,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['9 Saint Marks Pl',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '591ddfde31ac6c01ff11cbab',
#     'name': 'Joe Coffee',
#     'location': {'address': 'Oculus Passage',
#      'crossStreet': '2nd Floor',
#      'lat': 40.71252564484899,
#      'lng': -74.01313719970219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71252564484899,
#        'lng': -74.01313719970219}],
#      'distance': 361,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Oculus Passage (2nd Floor)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '5b9a8251cf72a0002c3c08a4',
#     'name': 'The Bar at Condé Nast',
#     'location': {'address': '285 Fulton St',
#      'crossStreet': 'at West Street',
#      'lat': 40.712703,
#      'lng': -74.01326,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.712703,
#        'lng': -74.01326}],
#      'distance': 339,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['285 Fulton St (at West Street)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '5665c7b9498e7d8a4f2c0f06',
#       'name': 'Corporate Coffee Shop',
#       'pluralName': 'Corporate Coffee Shops',
#       'shortName': 'Corporate Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False},
#    {'id': '49ee2410f964a52029681fe3',
#     'name': 'Starbucks',
#     'location': {'address': '200 Liberty St',
#      'crossStreet': 'at S End Ave',
#      'lat': 40.71102554,
#      'lng': -74.01545811,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71102554,
#        'lng': -74.01545811},
#       {'label': 'entrance', 'lat': 40.711152, 'lng': -74.015299}],
#      'distance': 459,
#      'postalCode': '10281',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 Liberty St (at S End Ave)',
#       'New York, NY 10281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591856194',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                  name  \
# 0  5dba113267232c000803cb37              For Five Coffee Roasters
# 1  4f241551e4b01b0c5f0f1361                        WFM Coffee Bar
# 2  50a38463e4b0d1371722335f           Hudson/Chambers Coffee Cart
# 3  4e4dd91ebd41b76bef941ef0                    The Coffee Beanery
# 4  5bbb56cba306190039f416a4  Coffee by La Colombe Coffee Roasters
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1591856194    False
# 1  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1591856194    False
# 2  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1591856194    False
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1591856194    False
# 4  [{'id': '5665c7b9498e7d8a4f2c0f06', 'name': 'C...  v-1591856194    False
#
#    location.lat  location.lng  \
# 0     40.712240    -74.014915
# 1     40.715542    -74.011436
# 2     40.715638    -74.009613
# 3     40.714629    -74.015819
# 4     40.713416    -74.015191
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.71224, 'lng': ...                329
# 1  [{'label': 'display', 'lat': 40.71554183959961...                358
# 2  [{'label': 'display', 'lat': 40.71563827489798...                512
# 3  [{'label': 'display', 'lat': 40.71462886707579...                 59
# 4  [{'label': 'display', 'lat': 40.713416, 'lng':...                196
#
#   location.postalCode location.cc location.city location.state  \
# 0               10280          US      New York             NY
# 1               10007          US      New York             NY
# 2               10007          US      New York             NY
# 3               07310          US   Jersey City             NY
# 4               10007          US      New York             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States                [New York, NY 10280, United States]
# 1    United States  [270 Greenwich St (Warren St), New York, NY 10...
# 2    United States  [Chambers St (at Hudson St), New York, NY 1000...
# 3    United States  [30 Mall Dr W, Jersey City, NY 07310, United S...
# 4    United States                [New York, NY 10007, United States]
#
#    location.address location.crossStreet venuePage.id location.neighborhood
# 0               NaN                  NaN          NaN                   NaN
# 1  270 Greenwich St            Warren St          NaN                   NaN
# 2       Chambers St         at Hudson St          NaN                   NaN
# 3      30 Mall Dr W                  NaN          NaN                   NaN
# 4               NaN                  NaN          NaN                   NaN

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                     name                 categories  \
# 0               For Five Coffee Roasters                Coffee Shop
# 1                         WFM Coffee Bar                Coffee Shop
# 2            Hudson/Chambers Coffee Cart                 Food Truck
# 3                     The Coffee Beanery                Coffee Shop
# 4   Coffee by La Colombe Coffee Roasters      Corporate Coffee Shop
# 5                   3rd Floor Coffee Bar      Corporate Coffee Shop
# 6              Laughing Man Coffee & Tea                Coffee Shop
# 7                            Coffee Cart                Coffee Shop
# 8       Coffee Cart (South End & Albany)             Breakfast Spot
# 9                 38th floor coffee cart                Coffee Shop
# 10                        Coffee & Lunch  Cajun / Creole Restaurant
# 11               Jack’s Stir Brew Coffee                Coffee Shop
# 12           Coffee Cuisine of Church St                       Food
# 13                  Sky Lobby Coffee Bar        Corporate Cafeteria
# 14                    Le District Coffee                Coffee Shop
# 15             Laughing Man Coffee & Tea                Coffee Shop
# 16                  Coffee &  Donut Cart                 Food Truck
# 17               MBJ Coffee Kiosk @ BMCC                       Café
# 18                          I m a coffee                       Café
# 19                            Joe Coffee                Coffee Shop
# 20                 The Bar at Condé Nast      Corporate Coffee Shop
# 21                             Starbucks                Coffee Shop
#
#           lat        lng                                     labeledLatLngs  \
# 0   40.712240 -74.014915  [{'label': 'display', 'lat': 40.71224, 'lng': ...
# 1   40.715542 -74.011436  [{'label': 'display', 'lat': 40.71554183959961...
# 2   40.715638 -74.009613  [{'label': 'display', 'lat': 40.71563827489798...
# 3   40.714629 -74.015819  [{'label': 'display', 'lat': 40.71462886707579...
# 4   40.713416 -74.015191  [{'label': 'display', 'lat': 40.713416, 'lng':...
# 5   40.714757 -74.014329  [{'label': 'display', 'lat': 40.71475688776351...
# 6   40.714754 -74.017368  [{'label': 'display', 'lat': 40.71475351814522...
# 7   40.715331 -74.011562  [{'label': 'display', 'lat': 40.71533065202649...
# 8   40.711431 -74.015842  [{'label': 'display', 'lat': 40.71143109488717...
# 9   40.714011 -74.013645  [{'label': 'display', 'lat': 40.71401058638798...
# 10  40.711542 -74.012841  [{'label': 'display', 'lat': 40.71154197506222...
# 11  40.716450 -74.009755  [{'label': 'display', 'lat': 40.71645048567266...
# 12  40.712952 -74.009491  [{'label': 'display', 'lat': 40.712952, 'lng':...
# 13  40.714708 -74.014404  [{'label': 'display', 'lat': 40.71470811444494...
# 14  40.713284 -74.015854  [{'label': 'display', 'lat': 40.71328360114957...
# 15  40.717394 -74.010103  [{'label': 'display', 'lat': 40.7173944529165,...
# 16  40.712689 -74.009985  [{'label': 'display', 'lat': 40.71268922492194...
# 17  40.716990 -74.012021  [{'label': 'display', 'lat': 40.7169900862958,...
# 18  40.729485 -73.989059  [{'label': 'display', 'lat': 40.72948455810547...
# 19  40.712526 -74.013137  [{'label': 'display', 'lat': 40.71252564484899...
# 20  40.712703 -74.013260  [{'label': 'display', 'lat': 40.712703, 'lng':...
# 21  40.711026 -74.015458  [{'label': 'display', 'lat': 40.71102554, 'lng...
#
#     distance postalCode  cc         city state        country  \
# 0        329      10280  US     New York    NY  United States
# 1        358      10007  US     New York    NY  United States
# 2        512      10007  US     New York    NY  United States
# 3         59      07310  US  Jersey City    NY  United States
# 4        196      10007  US     New York    NY  United States
# 5        120      10282  US     New York    NY  United States
# 6        150      10282  US     New York    NY  United States
# 7        346        NaN  US     New York    NY  United States
# 8        414      10280  US     New York    NY  United States
# 9        211      10281  US     New York    NY  United States
# 10       466      10007  US     New York    NY  United States
# 11       518      10013  US     New York    NY  United States
# 12       574      10007  US     New York    NY  United States
# 13       116      10282  US     New York    NY  United States
# 14       208      10281  US     New York    NY  United States
# 15       531      10013  US     New York    NY  United States
# 16       551        NaN  US     New York    NY  United States
# 17       369      10013  US     New York    NY  United States
# 18      2753      10003  US     New York    NY  United States
# 19       361      10007  US     New York    NY  United States
# 20       339      10007  US     New York    NY  United States
# 21       459      10281  US     New York    NY  United States
#
#                                      formattedAddress  \
# 0                 [New York, NY 10280, United States]
# 1   [270 Greenwich St (Warren St), New York, NY 10...
# 2   [Chambers St (at Hudson St), New York, NY 1000...
# 3   [30 Mall Dr W, Jersey City, NY 07310, United S...
# 4                 [New York, NY 10007, United States]
# 5   [200 West St (Murray St), New York, NY 10282, ...
# 6    [1 N End Ave, New York, NY 10282, United States]
# 7   [Greenwich St & Murray St, New York, NY, Unite...
# 8                 [New York, NY 10280, United States]
# 9   [200 Vesey St, New York, NY 10281, United States]
# 10  [185 Greenwich St, New York, NY 10007, United ...
# 11  [139 Reade St (Hudson/Greenwich), New York, NY...
# 12  [100 Church St, New York, NY 10007, United Sta...
# 13  [200 West St (at Murray St.), New York, NY 102...
# 14  [225 Liberty St (at West St), New York, NY 102...
# 15  [184 Duane St (btwn Greenwich & Hudson St.), N...
# 16  [Barclay st (Church st), New York, NY, United ...
# 17  [199 Chambers St, New York, NY 10013, New York...
# 18  [9 Saint Marks Pl, New York, NY 10003, United ...
# 19  [Oculus Passage (2nd Floor), New York, NY 1000...
# 20  [285 Fulton St (at West Street), New York, NY ...
# 21  [200 Liberty St (at S End Ave), New York, NY 1...
#
#                                 address                  crossStreet  \
# 0                                   NaN                          NaN
# 1                      270 Greenwich St                    Warren St
# 2                           Chambers St                 at Hudson St
# 3                          30 Mall Dr W                          NaN
# 4                                   NaN                          NaN
# 5                           200 West St                    Murray St
# 6                           1 N End Ave                          NaN
# 7                                   NaN     Greenwich St & Murray St
# 8                                   NaN                          NaN
# 9                          200 Vesey St                          NaN
# 10                     185 Greenwich St                          NaN
# 11                         139 Reade St             Hudson/Greenwich
# 12                        100 Church St                          NaN
# 13                          200 West St                at Murray St.
# 14                       225 Liberty St                   at West St
# 15                         184 Duane St  btwn Greenwich & Hudson St.
# 16                           Barclay st                    Church st
# 17  199 Chambers St, New York, NY 10013                          NaN
# 18                     9 Saint Marks Pl                          NaN
# 19                       Oculus Passage                    2nd Floor
# 20                        285 Fulton St               at West Street
# 21                       200 Liberty St                 at S End Ave
#
#           neighborhood                        id
# 0                  NaN  5dba113267232c000803cb37
# 1                  NaN  4f241551e4b01b0c5f0f1361
# 2                  NaN  50a38463e4b0d1371722335f
# 3                  NaN  4e4dd91ebd41b76bef941ef0
# 4                  NaN  5bbb56cba306190039f416a4
# 5                  NaN  58ece658424f93769dfd45d5
# 6                  NaN  50202b0ee4b0cabb110c01a2
# 7                  NaN  4e6ded5e45dd293273a36c79
# 8                  NaN  502a4fe7e4b0930e7b11b3c0
# 9                  NaN  5214cdc411d2f67e0de859f4
# 10  Financial District  4fc3bca5e4b0557039dd4ccd
# 11                 NaN  597a11ccb2958f056b27c60d
# 12                 NaN  4f3215d419836c91c7b4493b
# 13                 NaN  4d89044e6daeb60c33a846e0
# 14                 NaN  57210afa498ecfbb8c1be6cc
# 15             Tribeca  4ea0afbf9adf1e334e4cc0e6
# 16                 NaN  4e7e41b87beb96a21aba4704
# 17                 NaN  4f7c472de4b09b8aeaed0826
# 18                 NaN  52a3a47e11d2b5d5943d33dc
# 19                 NaN  591ddfde31ac6c01ff11cbab
# 20                 NaN  5b9a8251cf72a0002c3c08a4
# 21                 NaN  49ee2410f964a52029681fe3

# %% [markdown]
# #### Let's visualize the Italian restaurants that are nearby

# %%
dataframe_filtered.name
# Out:
# 0                 For Five Coffee Roasters
# 1                           WFM Coffee Bar
# 2              Hudson/Chambers Coffee Cart
# 3                       The Coffee Beanery
# 4     Coffee by La Colombe Coffee Roasters
# 5                     3rd Floor Coffee Bar
# 6                Laughing Man Coffee & Tea
# 7                              Coffee Cart
# 8         Coffee Cart (South End & Albany)
# 9                   38th floor coffee cart
# 10                          Coffee & Lunch
# 11                 Jack’s Stir Brew Coffee
# 12             Coffee Cuisine of Church St
# 13                    Sky Lobby Coffee Bar
# 14                      Le District Coffee
# 15               Laughing Man Coffee & Tea
# 16                    Coffee &  Donut Cart
# 17                 MBJ Coffee Kiosk @ BMCC
# 18                            I m a coffee
# 19                              Joe Coffee
# 20                   The Bar at Condé Nast
# 21                               Starbucks
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 2. Explore a Given Venue
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### A. Let's explore the closest Italian restaurant -- _Harry's Italian Pizza Bar_

# %%
venue_id = '5dba113267232c000803cb37' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/5dba113267232c000803cb37?client_id=IBFYFDBJUDEPCXTT1LLG3PXQBJNW5HOSGWS1GB0I2MM5COMC&client_secret=PT3YWES5EZX30CBHCEBXUSKCNDC0MBQXCSP4PPMY04BPIFJX&v=20180604'

# %% [markdown]
# #### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'seasonalHours', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto'])
# {'id': '5dba113267232c000803cb37',
#  'name': 'For Five Coffee Roasters',
#  'contact': {},
#  'location': {'lat': 40.71224,
#   'lng': -74.014915,
#   'labeledLatLngs': [{'label': 'display', 'lat': 40.71224, 'lng': -74.014915}],
#   'postalCode': '10280',
#   'cc': 'US',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['New York, NY 10280', 'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/for-five-coffee-roasters/5dba113267232c000803cb37',
#  'categories': [{'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'shortName': 'Coffee Shop',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 7},
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'},
#  'likes': {'count': 10,
#   'groups': [{'type': 'others', 'count': 10, 'items': []}],
#   'summary': '10 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 7.6,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 17,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 16,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 16,
#     'items': [{'id': '5e693197c74fb1000852e8b8',
#       'createdAt': 1583952279,
#       'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/23752_un8d6rVLArYPIoBV0e-21uyvM1sMZpvT_gf8JZCMz0M.jpg',
#       'width': 1440,
#       'height': 1920,
#       'user': {'id': '23752',
#        'firstName': 'Albert',
#        'lastName': 'C',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/23752-3TTJFGTW1PYDDZBW.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1572475186,
#  'tips': {'count': 7,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 7,
#     'items': [{'id': '5b88436f3092be002ca6a39c',
#       'createdAt': 1535656815,
#       'text': 'The americano is great!',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/5b88436f3092be002ca6a39c',
#       'lang': 'en',
#       'likes': {'count': 0, 'groups': []},
#       'logView': True,
#       'agreeCount': 1,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '48699',
#        'firstName': 'Kai',
#        'lastName': 'B',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/48699-XZV4CGW1M3GJ52VR.jpg'}}}]}]},
#  'shortUrl': 'https://4sq.com/2JAzESS',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 6,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 6,
#     'items': [{'id': '5e209f54d5de840006eabfed',
#       'name': 'New York Food 2020',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '325667684',
#        'firstName': 'Robin',
#        'lastName': 'J',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/325667684_0kMH-QIv_gKcQbEJdXEpND6kRsDbYOa5bp7umkTVeNPR3cOCN-Xb3sukEJnTG_lFdBjrSB7Z-.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': True,
#       'url': '/user/325667684/list/new-york-food-2020',
#       'canonicalUrl': 'https://foursquare.com/user/325667684/list/new-york-food-2020',
#       'createdAt': 1579196244,
#       'updatedAt': 1583477535,
#       'photo': {'id': '4f9d4b11e4b0609169758ffb',
#        'createdAt': 1335708433,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/lM3DZpib_gPHdQfOuy6AIKbguG793RUAFnOIak1739E.jpg',
#        'width': 540,
#        'height': 720,
#        'user': {'id': '19975508',
#         'firstName': 'Kenneth',
#         'lastName': 'B',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/A1JXZEIUA5JCXM0K.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 2},
#       'listItems': {'count': 60,
#        'items': [{'id': 'v5dba113267232c000803cb37',
#          'user': {'id': '528195296',
#           'firstName': 'Ruby',
#           'lastName': 'M',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/528195296_xP8iDPNS_LEvkS2MSN0rWTbMWA5FUa98TQPWXnsJ5Fr6q3TTYNrohYh6gxD03miKL_1emJrvo.jpg'},
#           'tips': {'count': 0},
#           'lists': {'groups': [{'type': 'created', 'count': 4, 'items': []}]},
#           'bio': ''},
#          'createdAt': 1582390127}]}},
#      {'id': '59590777491be746d8ef67a2',
#       'name': 'Coffee Shops to check out',
#       'description': 'Great (or curious) coffee shops I haven’t been to yet.',
#       'type': 'others',
#       'user': {'id': '1910079',
#        'firstName': 'Yossi',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/OGM4VD2TRYV05FBZ.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/yosefitche/list/coffee-shops-to-check-out',
#       'canonicalUrl': 'https://foursquare.com/yosefitche/list/coffee-shops-to-check-out',
#       'createdAt': 1499006839,
#       'updatedAt': 1543587029,
#       'photo': {'id': '50e9c8d9e4b02662bcd4ba94',
#        'createdAt': 1357498585,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/956544_z7tDATN0SM0FvhWSoCMcjjLBbKjoA_Hkr5DPbU26j9Q.jpg',
#        'width': 612,
#        'height': 612,
#        'user': {'id': '956544',
#         'firstName': 'Chris',
#         'lastName': 'B',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/956544_XOoLKuT2_hr-wTpkWkw_b4fIuMJ6u--n-P_VH3A00pNbXvJInLTwqatc_azLt4zmwWq6Ux4_M.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 0},
#       'listItems': {'count': 10,
#        'items': [{'id': 'v5dba113267232c000803cb37',
#          'createdAt': 1521075495}]}}]}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '9:00 AM–5:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '8:00 AM–4:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '10:00 AM–11:00 AM'}],
#     'segments': []},
#    {'days': 'Sun', 'open': [{'renderedTime': 'None'}], 'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '9:00 AM–5:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '8:00 AM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '8:00 AM–4:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '4a6fa0abf964a520a4d61fe3',
#   'name': 'Brookfield Place (BFPL)',
#   'location': {'address': '230 Vesey St',
#    'crossStreet': 'at West St',
#    'lat': 40.71324018931094,
#    'lng': -74.01519298553465,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71324018931094,
#      'lng': -74.01519298553465}],
#    'postalCode': '10281',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['230 Vesey St (at West St)',
#     'New York, NY 10281',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1fd941735',
#     'name': 'Shopping Mall',
#     'pluralName': 'Shopping Malls',
#     'shortName': 'Mall',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#      'suffix': '.png'},
#     'primary': True}]},
#  'hierarchy': [{'name': 'Brookfield Place (BFPL)',
#    'lang': 'en',
#    'id': '4a6fa0abf964a520a4d61fe3',
#    'canonicalUrl': 'https://foursquare.com/v/brookfield-place-bfpl/4a6fa0abf964a520a4d61fe3'}],
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Breakfast',
#     'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'}]}]},
#  'bestPhoto': {'id': '5e693197c74fb1000852e8b8',
#   'createdAt': 1583952279,
#   'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/23752_un8d6rVLArYPIoBV0e-21uyvM1sMZpvT_gf8JZCMz0M.jpg',
#   'width': 1440,
#   'height': 1920,
#   'visibility': 'public'}}

# %% [markdown]
# ### B. Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.6

# %% [markdown]
# That is not a very good rating. Let's check the rating of the second closest Italian restaurant.

# %%
venue_id = '52a3a47e11d2b5d5943d33dc' # ID of Conca Cucina Italian Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Since this restaurant has no ratings, let's check the third restaurant.

# %%
venue_id = '597a11ccb2958f056b27c60d' # ID of Ecco
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.8

# %% [markdown]
# Since this restaurant has a slightly better rating, let's explore it further.

# %% [markdown]
# ### C. Get the number of tips

# %%
result['response']['venue']['tips']['count']
# Out:
# 2

# %% [markdown]
# ### D. Get the venue's tips
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`/tips?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### Create URL and send GET request. Make sure to set limit to get all tips

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ee1cc42be946f5f08516642'},
#  'response': {'tips': {'count': 2,
#    'items': [{'id': '5d1a223e4f9e9600238ad558',
#      'createdAt': 1561993790,
#      'text': 'Cold brew and matcha donuts',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5d1a223e4f9e9600238ad558',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 2,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '53971514',
#       'firstName': 'Dan',
#       'lastName': 'E',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/53971514-WICEDBVSEOXXYGRC.jpg'}},
#      'authorInteractionType': 'liked'}]}}}

# %% [markdown]
# #### Get tips and list of associated features

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %% [markdown]
# #### Format column width and display all tips

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
# /Users/manjunathvhatkar/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                           text  agreeCount  disagreeCount  \
# 0  Cold brew and matcha donuts  2           0
#
#                          id user.firstName user.lastName  user.gender  \
# 0  5d1a223e4f9e9600238ad558  Dan            E            NaN
#
#     user.id
# 0  53971514

# %% [markdown]
# Now remember that because we are using a personal developer account, then we can access only 2 of the restaurant's tips, instead of all 15 tips.

# %% [markdown]
# ## 3. Search a Foursquare User
# > `https://api.foursquare.com/v2/users/`**USER_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### Define URL, send GET request and display features associated with user

# %%
user_id ='53971514' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
user_data = results['response']['user']

# display features associated with user
user_data.keys()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-940eaabbd2e3> in <module>
#       5 # send GET request
#       6 results = requests.get(url).json()
# ----> 7 user_data = results['response']['user']
#       8
#       9 # display features associated with user
#
# KeyError: 'user'

# %%
print('First Name: ' + user_data['firstName'])
print('Last Name: ' + user_data['lastName'])
print('Home City: ' + user_data['homeCity'])

# %% [markdown]
# #### How many tips has this user submitted?

# %%
user_data['tips']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6335e7dc938e> in <module>
# ----> 1 user_data['tips']
#
# NameError: name 'user_data' is not defined

# %% [markdown]
# Wow! So it turns out that Nick is a very active Foursquare user, with more than 250 tips.

# %% [markdown]
# ### Get User's tips

# %%
# define tips URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                                                                      text  \
# 0   This place is the best in town for breakfast and coffee. Get the burrito or a biscuit sandwich
# 1   This is the real Joe’s, and it’s the best. Not quite the same as the Carmine location but unbeatable in the area, and they take cards
# 2   HOLD THAT TIGER
# 3   Lots of great selections, including natural wines
# 4   Get a bottle of wine next store at their wine shop to enjoy with your tapas
# 5   Everything here is great. Don’t overthink it and don’t ask for suggestions or substitutions
# 6   This is Poulet Sans Tête. All the sides and chicken options are excellent, and delivery is reliable. Pulled means de-boned.
# 7   Pernil, and lots of hot sauce
# 8   Dope wine bar with good snacks. Read about the wines you’re going to try, and get the flights to try a variety.
# 9   Delightful doughnuts. Grab one of their whatever is special, and of course a classic like the glazed.
# 10  Lots of organic and healthy-ish options. Get some soup dumplings, a fried rice, and the Taiwanese beef noodle soup
# 11  Great coffees and matcha, and decent space to sit and work
# 12  Go for breakfast, get the chorizo burrito for $4, cash only, from the cart
# 13  Fantastic bakery and great lunch formula
# 14  Lots of delicious options, great for lunch, drinks, or dinner. Get some skewers and the truffle mac
#
#     agreeCount  disagreeCount                        id
# 0   0           0              5e480f399b9e0c0007339a3b
# 1   0           0              5e1bbccafd56440008d643e4
# 2   0           0              5e1bbc6fa259900007a6ce6e
# 3   0           0              5e1bbab5e5465d0006fc8107
# 4   0           0              5e1bba9a821fbb00067870b8
# 5   0           0              5e1bb9a8fa9296000aa0e29e
# 6   0           0              5e1bb95cfd56440008d2af43
# 7   0           0              5dfa72c7ac131a00066f5399
# 8   0           0              5dfa729b36f1760006df7cf9
# 9   0           0              5dfa725114981a000607c600
# 10  0           0              5dfa71fd952ca9000676e5e0
# 11  0           0              5dfa7155952ca90006752833
# 12  0           0              5dcdfb662d05d100069d9087
# 13  0           0              5dcc64d381107900060d0ea5
# 14  0           0              5dcc6400d9b9d80006c90c5f

# %%
tip_id = '5ab5575d73fe2516ad8f363b' # tip id

# define URL
url = 'http://api.foursquare.com/v2/tips/{}?client_id={}&client_secret={}&v={}'.format(tip_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tip']['venue']['name'])
print(result['response']['tip']['venue']['location'])
# Out:
# Cowgirl
# {'address': '519 Hudson St', 'crossStreet': 'at W 10th St', 'lat': 40.73373338282062, 'lng': -74.0062998849649, 'labeledLatLngs': [{'label': 'display', 'lat': 40.73373338282062, 'lng': -74.0062998849649}], 'postalCode': '10014', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['519 Hudson St (at W 10th St)', 'New York, NY 10014', 'United States']}

# %% [markdown]
# ### Get User's friends

# %%
user_friends = json_normalize(user_data['friends']['groups'][0]['items'])
user_friends
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-bcc27b1bf8b4> in <module>
# ----> 1 user_friends = json_normalize(user_data['friends']['groups'][0]['items'])
#       2 user_friends
#
# NameError: name 'user_data' is not defined

# %% [markdown]
# Interesting. Despite being very active, it turns out that Nick does not have any friends on Foursquare. This might definitely change in the future.

# %% [markdown]
# ### Retrieve the User's Profile Image

# %%
user_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-b61f3cd9c2fd> in <module>
# ----> 1 user_data
#
# NameError: name 'user_data' is not defined

# %%
# 1. grab prefix of photo
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://igx.4sqi.net/img/user/300x300/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg')
# Out:
# <img src="https://igx.4sqi.net/img/user/300x300/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg"/>

# %% [markdown]
# ## 4. Explore a location
# > `https://api.foursquare.com/v2/venues/`**explore**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### So, you just finished your gourmet dish at Ecco, and are just curious about the popular spots around the restaurant. In order to explore the area, let's start by getting the latitude and longitude values of Ecco Restaurant.

# %%
latitude = 40.715337
longitude = -74.008848

# %% [markdown]
# #### Define URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=IBFYFDBJUDEPCXTT1LLG3PXQBJNW5HOSGWS1GB0I2MM5COMC&client_secret=PT3YWES5EZX30CBHCEBXUSKCNDC0MBQXCSP4PPMY04BPIFJX&ll=40.715337,-74.008848&v=20180604&radius=500&limit=30'

# %% [markdown]
# #### Send GET request and examine results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Ecco restaurant.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '54148bc6498ea7bb8c05b70a',
#   'name': 'Juice Press',
#   'location': {'address': '83 Murray St',
#    'crossStreet': 'btwn Greenwich St & W Broadway',
#    'lat': 40.71478769908051,
#    'lng': -74.0111317502157,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71478769908051,
#      'lng': -74.0111317502157}],
#    'distance': 202,
#    'postalCode': '10007',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['83 Murray St (btwn Greenwich St & W Broadway)',
#     'New York, NY 10007',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1d3941735',
#     'name': 'Vegetarian / Vegan Restaurant',
#     'pluralName': 'Vegetarian / Vegan Restaurants',
#     'shortName': 'Vegetarian / Vegan',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-54148bc6498ea7bb8c05b70a-0'}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                       name                     categories  \
# 0  Juice Press              Vegetarian / Vegan Restaurant
# 1  Korin                    Furniture / Home Store
# 2  Los Tacos No. 1          Taco Place
# 3  Takahachi Bakery         Bakery
# 4  Takahachi                Sushi Restaurant
# 5  Exceed Physical Culture  Gym / Fitness Center
# 6  Equinox Tribeca          Gym
# 7  Whole Foods Market       Grocery Store
# 8  Chambers Street Wines    Wine Shop
# 9  Nish Nūsh                Falafel Restaurant
#
#                 address                     crossStreet        lat        lng  \
# 0  83 Murray St          btwn Greenwich St & W Broadway  40.714788 -74.011132
# 1  57 Warren St          Church St                       40.714824 -74.009404
# 2  136 Church St         NaN                             40.714267 -74.008756
# 3  25 Murray St          at Church St                    40.713653 -74.008804
# 4  145 Duane St          btwn W Broadway & Church St     40.716526 -74.008101
# 5  97 Reade St           bet W Broadway & Church St      40.715629 -74.007992
# 6  54 Murray St          at W Broadway                   40.714099 -74.009686
# 7  270 Greenwich Street  at Warren St                    40.715579 -74.011368
# 8  148 Chambers St       btwn West Broadway & Hudson St  40.715773 -74.009718
# 9  88 Reade St           at Church St                    40.715537 -74.007725
#
#                                                                                                                             labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 40.71478769908051, 'lng': -74.0111317502157}]
# 1  [{'label': 'display', 'lat': 40.71482437714839, 'lng': -74.00940425461492}, {'label': 'entrance', 'lat': 40.714727, 'lng': -74.009399}]
# 2  [{'label': 'display', 'lat': 40.714267, 'lng': -74.008756}]
# 3  [{'label': 'display', 'lat': 40.713652845301894, 'lng': -74.0088038953017}, {'label': 'entrance', 'lat': 40.713716, 'lng': -74.008443}]
# 4  [{'label': 'display', 'lat': 40.71652647412374, 'lng': -74.00810108466207}, {'label': 'entrance', 'lat': 40.716508, 'lng': -74.007989}]
# 5  [{'label': 'display', 'lat': 40.7156286200256, 'lng': -74.0079922583853}, {'label': 'entrance', 'lat': 40.715589, 'lng': -74.008105}]
# 6  [{'label': 'display', 'lat': 40.71409860726041, 'lng': -74.0096857179283}]
# 7  [{'label': 'display', 'lat': 40.715579155420606, 'lng': -74.01136823958119}]
# 8  [{'label': 'display', 'lat': 40.715773063928374, 'lng': -74.00971823312332}, {'label': 'entrance', 'lat': 40.715696, 'lng': -74.00988}]
# 9  [{'label': 'display', 'lat': 40.71553710116416, 'lng': -74.00772452925565}, {'label': 'entrance', 'lat': 40.715615, 'lng': -74.00773}]
#
#    distance postalCode  cc      city state        country  \
# 0  202       10007      US  New York  NY    United States
# 1  73        10007      US  New York  NY    United States
# 2  119       10007      US  New York  NY    United States
# 3  187       10007      US  New York  NY    United States
# 4  146       10013      US  New York  NY    United States
# 5  79        10013      US  New York  NY    United States
# 6  154       10007      US  New York  NY    United States
# 7  214       10007      US  New York  NY    United States
# 8  88        10007      US  New York  NY    United States
# 9  97        10013      US  New York  NY    United States
#
#                                                                         formattedAddress  \
# 0  [83 Murray St (btwn Greenwich St & W Broadway), New York, NY 10007, United States]
# 1  [57 Warren St (Church St), New York, NY 10007, United States]
# 2  [136 Church St, New York, NY 10007, United States]
# 3  [25 Murray St (at Church St), New York, NY 10007, United States]
# 4  [145 Duane St (btwn W Broadway & Church St), New York, NY 10013, United States]
# 5  [97 Reade St (bet W Broadway & Church St), New York, NY 10013, United States]
# 6  [54 Murray St (at W Broadway), New York, NY 10007, United States]
# 7  [270 Greenwich Street (at Warren St), New York, NY 10007, United States]
# 8  [148 Chambers St (btwn West Broadway & Hudson St), New York, NY 10007, United States]
# 9  [88 Reade St (at Church St), New York, NY 10013, United States]
#
#   neighborhood                        id
# 0  NaN          54148bc6498ea7bb8c05b70a
# 1  Tribeca      4af5d65ff964a52091fd21e3
# 2  NaN          5d5f24ec09484500079aee00
# 3  NaN          4c154c9a77cea593c401d260
# 4  NaN          4a8f2f39f964a520471420e3
# 5  Tribeca      53910ac3498e57a5dc0eb160
# 6  NaN          4a6e331af964a52031d41fe3
# 7  Tribeca      49bc3b0af964a52020541fe3
# 8  NaN          4adcf23cf964a520cc6221e3
# 9  NaN          50ba9119e4b071a4bae6dc10

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5. Explore Trending Venues
# > `https://api.foursquare.com/v2/venues/`**trending**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ee1cd3165fdfb234d9af771'},
#  'response': {'venues': []}}

# %% [markdown]
# ### Check if any venues are trending at this time

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# ### Visualize trending venues

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %% [markdown]
# ### Thank you for completing this lab!
